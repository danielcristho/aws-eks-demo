# %%
# !hostname
# Out:
# jupyter-admin

# %%
# %pip install "ray[default, data, tune, serve, client]==2.11.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 106.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 82.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 140.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 78.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 127.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 138.6 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 kB 43.8 MB/s eta 0:00:00
# ...

# %%
import random
import string
from collections.abc import Generator

import ray
from ray.util import ActorPool

from dataclasses import dataclass

# %%
ray.init(address="ray://ray-cluster-kuberay-head-svc.ray.svc.cluster.local:10001", allow_multiple=True)
print("Connected to Ray Cluster:", ray.cluster_resources())
# Out:
# 2025-10-22 14:59:23,685	WARNING utils.py:1591 -- Python patch version mismatch: The cluster was started with:
#     Ray: 2.11.0
#     Python: 3.11.8
# This process on Ray Client was started with:
#     Ray: 2.11.0
#     Python: 3.11.6
# Connected to Ray Cluster: {'memory': 3675350631.0, 'node:__internal_head__': 1.0, 'node:100.64.137.195': 1.0, 'CPU': 2.0, 'object_store_memory': 1837675315.0}

# %%
ray.nodes()
# Out:
# [{'NodeID': 'da9c7ee35b3ead832d57fd633d810af83e9f9a6763b7f9f4cce5be5a',
#   'Alive': True,
#   'NodeManagerAddress': '100.64.137.195',
#   'NodeManagerHostname': 'ray-cluster-kuberay-head-544m7',
#   'NodeManagerPort': 45551,
#   'ObjectManagerPort': 41081,
#   'ObjectStoreSocketName': '/tmp/ray/session_2025-10-22_04-46-10_385586_7/sockets/plasma_store',
#   'RayletSocketName': '/tmp/ray/session_2025-10-22_04-46-10_385586_7/sockets/raylet',
#   'MetricsExportPort': 55824,
#   'NodeName': '100.64.137.195',
#   'RuntimeEnvAgentPort': 60236,
#   'alive': True,
#   'Resources': {'CPU': 2.0,
#    'node:__internal_head__': 1.0,
#    'object_store_memory': 1837675315.0,
#    'node:100.64.137.195': 1.0,
#    'memory': 3675350631.0},
#   'Labels': {'ray.io/node_id': 'da9c7ee35b3ead832d57fd633d810af83e9f9a6763b7f9f4cce5be5a'}}]
