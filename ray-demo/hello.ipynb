# %%
import random
import string
from collections.abc import Generator

import ray
from ray.util import ActorPool

from dataclasses import dataclass

# %%
ray.init(address="ray://10.21.79.111:10001")
print("Connected to Ray Cluster:", ray.cluster_resources())
# Out:
# 2025-10-14 16:32:54,713	INFO client_builder.py:244 -- Passing the following kwargs to ray.init() on the server: log_to_driver
# SIGTERM handler is not set because current thread is not the main thread.
# Connected to Ray Cluster: {'accelerator_type:G': 1.0, 'memory': 111754080870.0, 'GPU': 1.0, 'node:10.21.79.111': 1.0, 'object_store_memory': 12240656793.0, 'node:__internal_head__': 1.0, 'CPU': 24.0}
# (Predictor pid=1751) __init__ Predictor
# (Predictor pid=1763) __init__ Predictor
# (Predictor pid=1762) __init__ Predictor
# (Predictor pid=1761) __init__ Predictor
# (Predictor pid=1759) __init__ Predictor
# (Consumer pid=1752) __init__ Consumer
# (Consumer pid=1752) consume ['input-3-0', 'input-3-1', 'input-3-2', 'input-3-3', 'input-3-4', 'input-3-5', 'input-3-6', 'input-3-7', 'input-3-8', 'input-3-9']
# (Consumer pid=1750) __init__ Consumer
# (Consumer pid=1750) consume ['input-6-0', 'input-6-1', 'input-6-2', 'input-6-3', 'input-6-4', 'input-6-5', 'input-6-6', 'input-6-7', 'input-6-8', 'input-6-9']
# (Consumer pid=1753) __init__ Consumer
# (Consumer pid=1753) consume ['input-5-0', 'input-5-1', 'input-5-2', 'input-5-3', 'input-5-4', 'input-5-5', 'input-5-6', 'input-5-7', 'input-5-8', 'input-5-9']
# (Consumer pid=1760) __init__ Consumer
# (Consumer pid=1760) consume ['input-1-0', 'input-1-1', 'input-1-2', 'input-1-3', 'input-1-4', 'input-1-5', 'input-1-6', 'input-1-7', 'input-1-8', 'input-1-9']
# (Consumer pid=1765) __init__ Consumer
# (Consumer pid=1765) consume ['input-9-0', 'input-9-1', 'input-9-2', 'input-9-3', 'input-9-4', 'input-9-5', 'input-9-6', 'input-9-7', 'input-9-8', 'input-9-9']
# (Consumer pid=1748) __init__ Consumer
# (Consumer pid=1748) consume ['input-7-0', 'input-7-1', 'input-7-2', 'input-7-3', 'input-7-4', 'input-7-5', 'input-7-6', 'input-7-7', 'input-7-8', 'input-7-9']
# (Consumer pid=1755) __init__ Consumer
# (Consumer pid=1755) consume ['input-4-0', 'input-4-1', 'input-4-2', 'input-4-3', 'input-4-4', 'input-4-5', 'input-4-6', 'input-4-7', 'input-4-8', 'input-4-9']
# (Consumer pid=1758) __init__ Consumer
# (Consumer pid=1758) consume ['input-0-0', 'input-0-1', 'input-0-2', 'input-0-3', 'input-0-4', 'input-0-5', 'input-0-6', 'input-0-7', 'input-0-8', 'input-0-9']
# (Consumer pid=1771) __init__ Consumer
# (Consumer pid=1771) consume ['input-8-0', 'input-8-1', 'input-8-2', 'input-8-3', 'input-8-4', 'input-8-5', 'input-8-6', 'input-8-7', 'input-8-8', 'input-8-9']
# (Consumer pid=1756) __init__ Consumer
# (Consumer pid=1756) consume ['input-2-0', 'input-2-1', 'input-2-2', 'input-2-3', 'input-2-4', 'input-2-5', 'input-2-6', 'input-2-7', 'input-2-8', 'input-2-9']

# %%
@dataclass
class Prediction:
    key: str
    value: str


@ray.remote
class Predictor:
    def __init__(self):
        print("__init__ Predictor")

    def predict(self, input_keys: list[str]) -> list[Prediction]:
        return [Prediction(key=k, value=random.choice(string.ascii_letters)) for k in input_keys]

@ray.remote
class Consumer:
    def __init__(self, predictors: list[ray.actor.ActorHandle]):
        print("__init__ Consumer")
        self.predictors = predictors

    def consume(self, input_keys: list[str]) -> list[Prediction]:
        print(f"consume {input_keys}")

        predictor = random.choice(self.predictors)
        ref = predictor.predict.remote(input_keys)
        ref = ray.get(ref)
        return ref

# %%
def main():
    print("creating actors")
    num_predictors = 5
    predictors = [Predictor.remote() for _ in range(num_predictors)]

    num_consumers = 10
    consumers = [Consumer.remote(predictors) for _ in range(num_consumers)]

    pool = ActorPool(consumers)

    input_keys = [[f"input-{i}-{j}" for j in range(10)] for i in range(10)]
    results: Generator[list[Prediction], None, None] = pool.map_unordered(
        lambda a, v: a.consume.remote(v), input_keys
    )

    print("wait on results")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# creating actors
# wait on results
# [Prediction(key='input-1-0', value='E'), Prediction(key='input-1-1', value='q'), Prediction(key='input-1-2', value='q'), Prediction(key='input-1-3', value='s'), Prediction(key='input-1-4', value='F'), Prediction(key='input-1-5', value='W'), Prediction(key='input-1-6', value='A'), Prediction(key='input-1-7', value='q'), Prediction(key='input-1-8', value='I'), Prediction(key='input-1-9', value='m')]
# [Prediction(key='input-0-0', value='b'), Prediction(key='input-0-1', value='K'), Prediction(key='input-0-2', value='n'), Prediction(key='input-0-3', value='B'), Prediction(key='input-0-4', value='Q'), Prediction(key='input-0-5', value='F'), Prediction(key='input-0-6', value='v'), Prediction(key='input-0-7', value='i'), Prediction(key='input-0-8', value='m'), Prediction(key='input-0-9', value='p')]
# [Prediction(key='input-2-0', value='J'), Prediction(key='input-2-1', value='R'), Prediction(key='input-2-2', value='z'), Prediction(key='input-2-3', value='i'), Prediction(key='input-2-4', value='z'), Prediction(key='input-2-5', value='D'), Prediction(key='input-2-6', value='j'), Prediction(key='input-2-7', value='X'), Prediction(key='input-2-8', value='O'), Prediction(key='input-2-9', value='R')]
# [Prediction(key='input-4-0', value='t'), Prediction(key='input-4-1', value='K'), Prediction(key='input-4-2', value='Y'), Prediction(key='input-4-3', value='b'), Prediction(key='input-4-4', value='S'), Prediction(key='input-4-5', value='T'), Prediction(key='input-4-6', value='o'), Prediction(key='input-4-7', value='y'), Prediction(key='input-4-8', value='U'), Prediction(key='input-4-9', value='P')]
# [Prediction(key='input-9-0', value='K'), Prediction(key='input-9-1', value='H'), Prediction(key='input-9-2', value='z'), Prediction(key='input-9-3', value='z'), Prediction(key='input-9-4', value='V'), Prediction(key='input-9-5', value='r'), Prediction(key='input-9-6', value='o'), Prediction(key='input-9-7', value='j'), Prediction(key='input-9-8', value='q'), Prediction(key='input-9-9', value='N')]
# [Prediction(key='input-6-0', value='n'), Prediction(key='input-6-1', value='s'), Prediction(key='input-6-2', value='h'), Prediction(key='input-6-3', value='q'), Prediction(key='input-6-4', value='T'), Prediction(key='input-6-5', value='V'), Prediction(key='input-6-6', value='F'), Prediction(key='input-6-7', value='V'), Prediction(key='input-6-8', value='k'), Prediction(key='input-6-9', value='u')]
# [Prediction(key='input-7-0', value='t'), Prediction(key='input-7-1', value='J'), Prediction(key='input-7-2', value='L'), Prediction(key='input-7-3', value='D'), Prediction(key='input-7-4', value='q'), Prediction(key='input-7-5', value='g'), Prediction(key='input-7-6', value='N'), Prediction(key='input-7-7', value='p'), Prediction(key='input-7-8', value='n'), Prediction(key='input-7-9', value='z')]
# [Prediction(key='input-8-0', value='u'), Prediction(key='input-8-1', value='Q'), Prediction(key='input-8-2', value='L'), Prediction(key='input-8-3', value='S'), Prediction(key='input-8-4', value='m'), Prediction(key='input-8-5', value='L'), Prediction(key='input-8-6', value='R'), Prediction(key='input-8-7', value='U'), Prediction(key='input-8-8', value='l'), Prediction(key='input-8-9', value='l')]
# [Prediction(key='input-3-0', value='r'), Prediction(key='input-3-1', value='h'), Prediction(key='input-3-2', value='l'), Prediction(key='input-3-3', value='q'), Prediction(key='input-3-4', value='z'), Prediction(key='input-3-5', value='w'), Prediction(key='input-3-6', value='W'), Prediction(key='input-3-7', value='c'), Prediction(key='input-3-8', value='E'), Prediction(key='input-3-9', value='c')]
# [Prediction(key='input-5-0', value='U'), Prediction(key='input-5-1', value='w'), Prediction(key='input-5-2', value='i'), Prediction(key='input-5-3', value='A'), Prediction(key='input-5-4', value='X'), Prediction(key='input-5-5', value='p'), Prediction(key='input-5-6', value='X'), Prediction(key='input-5-7', value='l'), Prediction(key='input-5-8', value='c'), Prediction(key='input-5-9', value='w')]
